# %% [markdown]
# # Explore *hatecrime.csv*
# Questions:
# - How has the number of hate crimes changed over the years?
# - What are the proportions of bias of reported incidents each year?
#     - Within each bias category, bias against which group is most prevalent?
# - In each state, which bias category are most prevalent?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load clean_hatecrime.csv
hc = pd.read_csv("./../datasets/clean_hate_crime.csv")
# Out:
# C:\Users\tammi\AppData\Roaming\Python\Python38\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (18) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# ### How has the number of hate crimes changed over the years?

# %%
num_hc = pd.DataFrame(hc.groupby("year")["incident_id"].count())
num_hc.reset_index(inplace = True)
num_hc.columns = ["year","num_incidents"]
num_hc
# Out:
#     year  num_incidents
# 0   1991           4589
# 1   1992           6667
# 2   1993           7608
# 3   1994           5954
# 4   1995           7950
# 5   1996           8790
# 6   1997           8107
# 7   1998           7902
# 8   1999           7944
# 9   2000           8219
# 10  2001           9730
# 11  2002           7485
# 12  2003           7545
# 13  2004           7685
# 14  2005           7411
# 15  2006           7715
# 16  2007           7625
# 17  2008           8039
# 18  2009           6613
# 19  2010           6633
# 20  2011           6299
# 21  2012           6594
# 22  2013           6044
# 23  2014           5599
# 24  2015           5871
# 25  2016           6276
# 26  2017           7316
# 27  2018           7157
# 28  2019           7891
# 29  2020          10299

# %%
# Reported hate crime incidence from 1991-2020
num_hc_plot = num_hc.plot("year", "num_incidents")
#plt.savefig(num_hc_plot)

# %% [markdown]
# **Interpretation: The number of reported incidents have gone down since 2000's but is on the rise again since 2015.**

# %% [markdown]
# ### What are the proportions of bias of reported incidents each year?

# %%
# Gather what type of biases are recorded
biases = []
for bias in hc["bias_desc"]:
    if ";" not in bias and bias not in biases:
        biases.append(bias)
    elif ";" in bias:
        # Take into account when multiple biases recorded
        sub_biases = bias.split(";")
        for sub_bias in sub_biases:
            if sub_bias not in biases:
                biases.append(sub_bias)    
biases
# Out:
# ['Anti-Black or African American',
#  'Anti-White',
#  'Anti-Jewish',
#  'Anti-Arab',
#  'Anti-Protestant',
#  'Anti-Other Religion',
#  'Anti-Islamic (Muslim)',
#  'Anti-Gay (Male)',
#  'Anti-Asian',
#  'Anti-Catholic',
#  'Anti-Heterosexual',
#  'Anti-Hispanic or Latino',
#  'Anti-Other Race/Ethnicity/Ancestry',
#  'Anti-Multiple Religions, Group',
#  'Anti-Multiple Races, Group',
#  'Anti-Lesbian (Female)',
#  'Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)',
#  'Anti-American Indian or Alaska Native',
#  'Anti-Atheism/Agnosticism',
#  'Anti-Bisexual',
#  'Anti-Physical Disability',
#  'Anti-Mental Disability',
#  'Anti-Gender Non-Conforming',
#  'Anti-Female',
#  'Anti-Transgender',
#  'Anti-Native Hawaiian or Other Pacific Islander',
#  'Anti-Male',
#  "Anti-Jehovah's Witness",
#  'Anti-Mormon',
#  'Anti-Buddhist',
#  'Anti-Sikh',
#  'Anti-Other Christian',
#  'Anti-Hindu',
#  'Anti-Eastern Orthodox (Russian, Greek, Other)',
#  "Unknown (offender's motivation not known)"]

# %%
# Create bias categories: race/ethnicity (race/ethn), "sex", "lgbt", "religion", "disability", "other"
bias_cat_dic = {"race/ethn": ['Anti-Black or African American', 'Anti-White','Anti-Arab',
                              'Anti-Asian', 'Anti-Hispanic or Latino','Anti-Other Race/Ethnicity/Ancestry',
                              'Anti-Multiple Races, Group', 'Anti-American Indian or Alaska Native',
                              'Anti-Native Hawaiian or Other Pacific Islander',
                              'Anti-Eastern Orthodox (Russian, Greek, Other)'],
               "sex": ['Anti-Female', 'Anti-Male'],
               "lgbt": ['Anti-Gay (Male)','Anti-Heterosexual','Anti-Lesbian (Female)',
                        'Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)','Anti-Bisexual',
                       'Anti-Gender Non-Conforming','Anti-Transgender',],
               "religion":['Anti-Jewish','Anti-Protestant','Anti-Other Religion','Anti-Islamic (Muslim)',
                          'Anti-Catholic','Anti-Multiple Religions, Group','Anti-Atheism/Agnosticism', 
                           "Anti-Jehovah's Witness",'Anti-Mormon','Anti-Buddhist','Anti-Sikh',
                           'Anti-Other Christian','Anti-Hindu',],
               "disability":['Anti-Physical Disability','Anti-Mental Disability'],
               "other":["Unknown (offender's motivation not known)"]}

# %%
# ID what bias category each hate crime incidence is and add to dataframe
bias_cat = []
for bias in hc["bias_desc"]:
    if ";" not in bias:
        for key in bias_cat_dic:
            bias_lst = bias_cat_dic[key]
            if bias in bias_lst:
                bias_cat.append(key)
                break
    elif ";" in bias:
        # for incidents with more than one biases (these bias_cat begins with "mix")
        sub_biases = bias.split(";")
        temp_cat = "mix"
        for sub_bias in sub_biases:
            for key in bias_cat_dic:
                bias_lst = bias_cat_dic[key]
                if sub_bias in bias_lst:
                    temp_cat = temp_cat + "," + key
                    break
        bias_cat.append(temp_cat)

# %%
# Add bias category to dataframe
hc["bias_cat"] = bias_cat

# %%
# hc without mix bias
nomix_hc = hc[~hc["bias_cat"].str.contains("mix")]
nomix_hc
# Out:
#         Unnamed: 0  incident_id  year pub_agency_name agency_type_name  \
# 0                0         3015  1991          Rogers             City
# 1                1         3016  1991            Hope             City
# 2                2           43  1991      Pine Bluff             City
# 3                3           44  1991      Pine Bluff             City
# 4                4         3017  1991      Pine Bluff             City
# ...            ...          ...   ...             ...              ...
# 219552      219572      1318026  2020        Sheridan             City
# 219553      219573      1142103  2020        Evanston             City
# 219554      219574      1318018  2020        Evanston             City
# 219555      219575      1318022  2020        Evanston             City
# 219556      219576      1318023  2020        Evanston             City
#
#        state_abbr state_name       division_name region_name  \
# 0              AR   Arkansas  West South Central       South
# 1              AR   Arkansas  West South Central       South
# 2              AR   Arkansas  West South Central       South
# 3              AR   Arkansas  West South Central       South
# 4              AR   Arkansas  West South Central       South
# ...           ...        ...                 ...         ...
# 219552         WY    Wyoming            Mountain        West
# 219553         WY    Wyoming            Mountain        West
# 219554         WY    Wyoming            Mountain        West
# 219555         WY    Wyoming            Mountain        West
# 219556         WY    Wyoming            Mountain        West
#
#        population_group_code  ...      offender_ethnicity victim_count  \
# 0                          5  ...                     NaN            1
# 1                          6  ...                     NaN            1
# 2                          3  ...                     NaN            1
# 3                          3  ...                     NaN            2
# 4                          3  ...                     NaN            1
# ...                      ...  ...                     ...          ...
# 219552                     5  ...  Not Hispanic or Latino            2
# 219553                     5  ...                 Unknown            1
# 219554                     5  ...  Not Hispanic or Latino            1
# 219555                     5  ...  Not Hispanic or Latino            1
# 219556                     5  ...  Not Hispanic or Latino            1
#
#                                              offense_name  \
# 0                                            Intimidation
# 1                                          Simple Assault
# 2                                      Aggravated Assault
# 3       Aggravated Assault;Destruction/Damage/Vandalis...
# 4                                      Aggravated Assault
# ...                                                   ...
# 219552                                       Intimidation
# 219553           Destruction/Damage/Vandalism of Property
# 219554                                 Aggravated Assault
# 219555                                     Simple Assault
# 219556                                Theft From Building
#
#         total_individual_victims                       location_name  \
# 0                            1.0  Highway/Road/Alley/Street/Sidewalk
# 1                            1.0  Highway/Road/Alley/Street/Sidewalk
# 2                            1.0                      Residence/Home
# 3                            1.0  Highway/Road/Alley/Street/Sidewalk
# 4                            1.0                 Service/Gas Station
# ...                          ...                                 ...
# 219552                       2.0                     Park/Playground
# 219553                       0.0                     Park/Playground
# 219554                       1.0                      Residence/Home
# 219555                       1.0                      Residence/Home
# 219556                       1.0                      Residence/Home
#
#                                                 bias_desc  victim_types  \
# 0                          Anti-Black or African American    Individual
# 1                                              Anti-White    Individual
# 2                          Anti-Black or African American    Individual
# 3                                              Anti-White    Individual
# 4                                              Anti-White    Individual
# ...                                                   ...           ...
# 219552  Anti-Lesbian, Gay, Bisexual, or Transgender (M...    Individual
# 219553                                         Anti-White    Government
# 219554                                         Anti-White    Individual
# 219555                                        Anti-Female    Individual
# 219556                         Anti-Gender Non-Conforming    Individual
#
#        multiple_offense multiple_bias   bias_cat
# 0                     S             S  race/ethn
# 1                     S             S  race/ethn
# 2                     S             S  race/ethn
# 3                     M             S  race/ethn
# 4                     S             S  race/ethn
# ...                 ...           ...        ...
# 219552                S             S       lgbt
# 219553                S             S  race/ethn
# 219554                S             S  race/ethn
# 219555                S             S        sex
# 219556                S             S       lgbt
#
# [218538 rows x 28 columns]

# %%
# Create num bias category each year (all, including mix)
num_bias_hc = pd.DataFrame(hc.groupby(["year","bias_cat"])["incident_id"].count())
num_bias_hc.reset_index(inplace = True)
num_bias_hc.columns = ["year", "bias_cat", "num_bias_cat"]
num_bias_hc["prop_bias"] = num_bias_hc["num_bias_cat"]/num_bias_hc.groupby("year")["num_bias_cat"].transform("sum")
num_bias_hc
# Out:
#      year                 bias_cat  num_bias_cat  prop_bias
# 0    1991                     lgbt           405   0.088255
# 1    1991       mix,lgbt,race/ethn             2   0.000436
# 2    1991        mix,lgbt,religion             1   0.000218
# 3    1991       mix,race/ethn,lgbt             2   0.000436
# 4    1991  mix,race/ethn,race/ethn             2   0.000436
# ..    ...                      ...           ...        ...
# 337  2020        mix,sex,race/ethn             4   0.000388
# 338  2020         mix,sex,religion             1   0.000097
# 339  2020                race/ethn          6564   0.637343
# 340  2020                 religion          1556   0.151083
# 341  2020                      sex            85   0.008253
#
# [342 rows x 4 columns]

# %% [markdown]
# **Since so few mix bias_cat, omitting it below for further analysis**

# %%
# Create num bias category each year (no mix)
num_bias_hc = pd.DataFrame(nomix_hc.groupby(["year","bias_cat"])["incident_id"].count())
num_bias_hc.reset_index(inplace = True)
num_bias_hc.columns = ["year", "bias_cat", "num_bias_cat"]
num_bias_hc["prop_bias"] = num_bias_hc["num_bias_cat"]/num_bias_hc.groupby("year")["num_bias_cat"].transform("sum")
num_bias_hc
# Out:
#      year    bias_cat  num_bias_cat  prop_bias
# 0    1991        lgbt           405   0.088409
# 1    1991   race/ethn          3263   0.712290
# 2    1991    religion           913   0.199301
# 3    1992        lgbt           773   0.115962
# 4    1992   race/ethn          4728   0.709271
# ..    ...         ...           ...        ...
# 119  2020  disability           174   0.017530
# 120  2020        lgbt          1547   0.155853
# 121  2020   race/ethn          6564   0.661294
# 122  2020    religion          1556   0.156760
# 123  2020         sex            85   0.008563
#
# [124 rows x 4 columns]

# %%
# rearrange columns of num_bias_hc in order to make box plot
num_bias_hc_t = {}
for bias in bias_cat_dic.keys():
    bias_rows = list(num_bias_hc[num_bias_hc["bias_cat"] == bias]["num_bias_cat"])
    while len(bias_rows) < 30:
        bias_rows = [0] + bias_rows
    num_bias_hc_t[bias] = bias_rows
num_bias_hc_t_df = pd.DataFrame(num_bias_hc_t, index = range(1991,2021))
num_bias_hc_t_df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
# Plot of each type of bias's raw num over time
num_bias_hc_plt = sns.lineplot(data = num_bias_hc[["year", "num_bias_cat", "bias_cat"]], x = "year", y = "num_bias_cat", hue = "bias_cat")

# %%
# Plot of each type of bias's raw num over time
for key in bias_cat_dic:
    num_bias_hc[num_bias_hc["bias_cat"]==key].plot(x="year", y = "num_bias_cat", title = key)

# %%
# rearrange columns of num_bias_hc in order to make box plot
num_bias_hc_t = {}
for bias in bias_cat_dic.keys():
    bias_rows = list(num_bias_hc[num_bias_hc["bias_cat"] == bias]["prop_bias"])
    while len(bias_rows) < 30:
        bias_rows = [0] + bias_rows
    num_bias_hc_t[bias] = bias_rows
num_bias_hc_t_df = pd.DataFrame(num_bias_hc_t, index = range(1991,2021))
num_bias_hc_t_df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(data = num_bias_hc, x = "year", y = "prop_bias", hue = "bias_cat")
# Out:
# <AxesSubplot:xlabel='year', ylabel='prop_bias'>

# %%
# Plot of each type of bias's proportion over time
for key in bias_cat_dic:
    num_bias_hc[num_bias_hc["bias_cat"]==key].plot(x="year", y = "prop_bias", title = key)

# %% [markdown]
# #### Within race/ethn category, how does racial bias change over time?

# %%
# num of each specific racial bias over years
racebias_hc = pd.DataFrame(hc[hc["bias_cat"] == "race/ethn"].groupby(["year", "bias_desc"])["incident_id"].count())
racebias_hc.reset_index(inplace = True)
racebias_hc.columns = ["year", "bias_desc", "num_race_incident"]
racebias_hc["prop_bias"] = racebias_hc["num_race_incident"]/racebias_hc.groupby("year")["num_race_incident"].transform("sum")
racebias_hc
# Out:
#      year                                       bias_desc  num_race_incident  \
# 0    1991           Anti-American Indian or Alaska Native                 11
# 1    1991                                       Anti-Arab                 73
# 2    1991                                      Anti-Asian                269
# 3    1991                  Anti-Black or African American               1624
# 4    1991                         Anti-Hispanic or Latino                231
# ..    ...                                             ...                ...
# 239  2020                         Anti-Hispanic or Latino                622
# 240  2020                      Anti-Multiple Races, Group                245
# 241  2020  Anti-Native Hawaiian or Other Pacific Islander                 29
# 242  2020              Anti-Other Race/Ethnicity/Ancestry                347
# 243  2020                                      Anti-White               1186
#
#      prop_bias
# 0     0.003371
# 1     0.022372
# 2     0.082439
# 3     0.497702
# 4     0.070794
# ..         ...
# 239   0.094759
# 240   0.037325
# 241   0.004418
# 242   0.052864
# 243   0.180683
#
# [244 rows x 4 columns]

# %%
# rearrange columns of num_bias_hc in order to make box plot
racebias_hc_t = {}
for bias in bias_cat_dic["race/ethn"]:
    bias_rows = list(racebias_hc[racebias_hc["bias_desc"] == bias]["num_race_incident"])
    while len(bias_rows) < 30:
        bias_rows = [0] + bias_rows
    racebias_hc_t[bias] = bias_rows
racebias_hc_t_df = pd.DataFrame(racebias_hc_t, index = range(1991,2021))
racebias_hc_t_df.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:>

# %%
# Plot of each type of bias's raw num over time
racebias_hc_plt = sns.lineplot(data = racebias_hc[["year", "num_race_incident", "bias_desc"]], x = "year", y = "num_race_incident", hue = "bias_desc")
racebias_hc_plt.legend(bbox_to_anchor=(2, 1), loc="upper right", borderaxespad=0)

# %%
# Plot num incidents over time for each racial cat
for race in bias_cat_dic["race/ethn"]:
    racebias_hc[racebias_hc["bias_desc"]==race].plot(x="year", y = "num_race_incident", title = race)

# %%
# rearrange columns of num_bias_hc in order to make box plot
racebias_hc_t = {}
for bias in bias_cat_dic["race/ethn"]:
    bias_rows = list(racebias_hc[racebias_hc["bias_desc"] == bias]["prop_bias"])
    while len(bias_rows) < 30:
        bias_rows = [0] + bias_rows
    racebias_hc_t[bias] = bias_rows
racebias_hc_t_df = pd.DataFrame(racebias_hc_t, index = range(1991,2021))
racebias_hc_t_df_plt = racebias_hc_t_df.plot(kind='bar', stacked=True)
racebias_hc_t_df_plt.legend(bbox_to_anchor=(2, 1), loc="upper right", borderaxespad=0)

# %%
# Plot of each type of bias's raw num over time
racebias_hc_plt = sns.lineplot(data = racebias_hc[["year", "prop_bias", "bias_desc"]], x = "year", y = "prop_bias", hue = "bias_desc")
racebias_hc_plt.legend(bbox_to_anchor=(2, 1), loc="upper right", borderaxespad=0)

# %%
# Plot num incidents over time for each racial cat
for race in bias_cat_dic["race/ethn"]:
    racebias_hc[racebias_hc["bias_desc"]==race].plot(x="year", y = "prop_bias", title = race)

# %% [markdown]
# ### In each state, which bias category are most prevalent?

# %%
# total incidence since 1990s of each bias category of each state
state_hc = pd.DataFrame(hc.groupby(["state_name", "bias_cat"])["incident_id"].count())
state_hc.reset_index(inplace = True)
state_hc.columns = ["state_name", "bias_cat", "num_bias_incident"]
state_hc["prop_bias"] = state_hc["num_bias_incident"]/state_hc.groupby("state_name")["num_bias_incident"].transform("sum")
state_hc
# Out:
#     state_name                bias_cat  num_bias_incident  prop_bias
# 0      Alabama              disability                  2   0.008658
# 1      Alabama                    lgbt                 19   0.082251
# 2      Alabama  mix,religion,race/ethn                  1   0.004329
# 3      Alabama               race/ethn                190   0.822511
# 4      Alabama                religion                 19   0.082251
# ..         ...                     ...                ...        ...
# 507  Wisconsin                     sex                  7   0.004271
# 508    Wyoming                    lgbt                 32   0.181818
# 509    Wyoming               race/ethn                110   0.625000
# 510    Wyoming                religion                 32   0.181818
# 511    Wyoming                     sex                  2   0.011364
#
# [512 rows x 4 columns]

# %%
states = [state[0] for state in hc.groupby("state_name")["state_name"]]
state_bias = []
most_bias = []
num_incident =[]
for state in states:
    state_df = state_hc[state_hc["state_name"] == state]
    max_num_incident = state_df["num_bias_incident"].max()
    most_bias = list(state_df[state_df["num_bias_incident"] == max_num_incident]["bias_cat"])[0]
    state_bias.append([state, most_bias, max_num_incident])
    
state_bias = pd.DataFrame(state_bias, columns = ["state", "most_bias", "num_incident"])
state_bias
# Out:
#                    state  most_bias  num_incident
# 0                Alabama  race/ethn           190
# 1                 Alaska  race/ethn           184
# 2                Arizona  race/ethn          4382
# 3               Arkansas  race/ethn           889
# 4             California  race/ethn         22569
# 5               Colorado  race/ethn          2902
# 6            Connecticut  race/ethn          2299
# 7               Delaware  race/ethn           604
# 8   District of Columbia       lgbt           888
# 9                Federal  race/ethn           218
# 10               Florida  race/ethn          3424
# 11               Georgia  race/ethn           846
# 12                  Guam  race/ethn             5
# 13                Hawaii  race/ethn            93
# 14                 Idaho  race/ethn           866
# 15              Illinois  race/ethn          3938
# 16               Indiana  race/ethn          1463
# 17                  Iowa  race/ethn           656
# 18                Kansas  race/ethn          1358
# 19              Kentucky  race/ethn          2574
# 20             Louisiana  race/ethn           373
# 21                 Maine  race/ethn           672
# 22              Maryland  race/ethn          4227
# 23         Massachusetts  race/ethn          6736
# 24              Michigan  race/ethn          9140
# 25             Minnesota  race/ethn          3353
# 26           Mississippi  race/ethn           127
# 27              Missouri  race/ethn          2539
# 28               Montana  race/ethn           421
# 29              Nebraska  race/ethn           818
# 30                Nevada  race/ethn          1228
# 31         New Hampshire  race/ethn           326
# 32            New Jersey  race/ethn         12134
# 33            New Mexico  race/ethn           363
# 34              New York   religion          8993
# 35        North Carolina  race/ethn          2042
# 36          North Dakota  race/ethn           332
# 37                  Ohio  race/ethn          6493
# 38              Oklahoma  race/ethn          1140
# 39                Oregon  race/ethn          2926
# 40          Pennsylvania  race/ethn          2700
# 41          Rhode Island  race/ethn           458
# 42        South Carolina  race/ethn          1431
# 43          South Dakota  race/ethn           432
# 44             Tennessee  race/ethn          2883
# 45                 Texas  race/ethn          5893
# 46                  Utah  race/ethn          1075
# 47               Vermont  race/ethn           323
# 48              Virginia  race/ethn          3920
# 49            Washington  race/ethn          5629
# 50         West Virginia  race/ethn           724
# 51             Wisconsin  race/ethn          1078
# 52               Wyoming  race/ethn           110

# %% [markdown]
# **Interpretation: Hate crimes in most states are most often due to race/ethnicity**

# %% [markdown]
# ### State -> city in California
# Where are the most crimes taking place (e.g. populated cities, rural towns, etc.)?
# Use population size to determine urban, sub, rural https://www.california-demographics.com/cities_by_population
# - city to county: https://www.statsamerica.org/CityCountyFinder/
# - urban, sub, rural: https://www.counties.org/sites/main/files/file-attachments/2020-june3-countycaucusesinfographic-4-final.pdf

# %%
# Make a dataframe with just california data
CA_hc = nomix_hc[nomix_hc["state_abbr"] == "CA"]

# %%
# Import county to city key
CA_c2c = pd.read_csv("../datasets/2020_CA_city_to_county.csv", )
CA_c2c.head()
# Out:
#              city          county county_cat
# 0  Acalanes Ridge    Contra Costa      urban
# 1          Acampo     San Joaquin      urban
# 2           Acton     Los Angeles      urban
# 3        Adelanto  San Bernardino      urban
# 4            Adin           Modoc      rural

# %%
# Annotating whether county is urban, suburban, and rural
county_cat = []
city_names = list(CA_c2c["city"])
for city in CA_hc["pub_agency_name"]:
    city = city.strip()
    if city in city_names:
        county_cat.append(list(CA_c2c[CA_c2c["city"]==city]["county_cat"])[0])
    elif city in county_cat_dic["urban"]:
        county_cat.append("urban")
    elif city in county_cat_dic["suburban"]:
        county_cat.append("suburban")
    elif city in county_cat_dic["rural"]:
        county_cat.append("rural")
    else:
        county_cat.append(None)

# %%
# Adding county_cat as a column to CA hc dataframe
CA_hc["county_cat"] = county_cat
CA_hc
# Out:
# <ipython-input-55-076386e23de2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   CA_hc["county_cat"] = county_cat
#         Unnamed: 0  incident_id  year pub_agency_name agency_type_name  \
# 60              60           48  1991    Garden Grove             City
# 61              61           49  1991    Garden Grove             City
# 62              62           50  1991    Garden Grove             City
# 63              63           51  1991    Garden Grove             City
# 64              64           52  1991    Garden Grove             City
# ...            ...          ...   ...             ...              ...
# 210961      210981      1262584  2020           Davis             City
# 210962      210982      1262585  2020           Davis             City
# 210963      210983      1262634  2020        Woodland             City
# 210964      210984      1262611  2020            Yuba           County
# 210965      210985      1262612  2020            Yuba           County
#
#        state_abbr  state_name division_name region_name population_group_code  \
# 60             CA  California       Pacific        West                     2
# 61             CA  California       Pacific        West                     2
# 62             CA  California       Pacific        West                     2
# 63             CA  California       Pacific        West                     2
# 64             CA  California       Pacific        West                     2
# ...           ...         ...           ...         ...                   ...
# 210961         CA  California       Pacific        West                     3
# 210962         CA  California       Pacific        West                     3
# 210963         CA  California       Pacific        West                     3
# 210964         CA  California       Pacific        West                    9B
# 210965         CA  California       Pacific        West                    9B
#
#         ... victim_count                              offense_name  \
# 60      ...            1                              Intimidation
# 61      ...            1                              Intimidation
# 62      ...            1                              Intimidation
# 63      ...            2                        Aggravated Assault
# 64      ...            1  Destruction/Damage/Vandalism of Property
# ...     ...          ...                                       ...
# 210961  ...            1                            Simple Assault
# 210962  ...            1                            Simple Assault
# 210963  ...            1                            Simple Assault
# 210964  ...            1  Destruction/Damage/Vandalism of Property
# 210965  ...            1                        Aggravated Assault
#
#         total_individual_victims                       location_name  \
# 60                           1.0                      School/College
# 61                           1.0                       Other/Unknown
# 62                           1.0                       Other/Unknown
# 63                           2.0             Parking/Drop Lot/Garage
# 64                           1.0                      Residence/Home
# ...                          ...                                 ...
# 210961                       1.0                      Residence/Home
# 210962                       1.0  Highway/Road/Alley/Street/Sidewalk
# 210963                       1.0  Highway/Road/Alley/Street/Sidewalk
# 210964                       1.0  Highway/Road/Alley/Street/Sidewalk
# 210965                       1.0                      Residence/Home
#
#                                  bias_desc  victim_types  multiple_offense  \
# 60          Anti-Black or African American    Individual                 S
# 61                             Anti-Jewish    Individual                 S
# 62                             Anti-Jewish    Individual                 S
# 63                              Anti-Asian    Individual                 S
# 64          Anti-Black or African American    Individual                 S
# ...                                    ...           ...               ...
# 210961  Anti-Other Race/Ethnicity/Ancestry    Individual                 S
# 210962  Anti-Other Race/Ethnicity/Ancestry    Individual                 S
# 210963      Anti-Black or African American    Individual                 S
# 210964      Anti-Black or African American    Individual                 S
# 210965      Anti-Black or African American    Individual                 S
#
#        multiple_bias   bias_cat  county_cat
# 60                 S  race/ethn       urban
# 61                 S   religion       urban
# 62                 S   religion       urban
# 63                 S  race/ethn       urban
# 64                 S  race/ethn       urban
# ...              ...        ...         ...
# 210961             S  race/ethn    suburban
# 210962             S  race/ethn    suburban
# 210963             S  race/ethn    suburban
# 210964             S  race/ethn       rural
# 210965             S  race/ethn       rural
#
# [36205 rows x 29 columns]

# %%
CA_county_hc = CA_hc[~CA_hc["county_cat"].isna()]
CA_county_hc
# Out:
#         Unnamed: 0  incident_id  year pub_agency_name agency_type_name  \
# 60              60           48  1991    Garden Grove             City
# 61              61           49  1991    Garden Grove             City
# 62              62           50  1991    Garden Grove             City
# 63              63           51  1991    Garden Grove             City
# 64              64           52  1991    Garden Grove             City
# ...            ...          ...   ...             ...              ...
# 210961      210981      1262584  2020           Davis             City
# 210962      210982      1262585  2020           Davis             City
# 210963      210983      1262634  2020        Woodland             City
# 210964      210984      1262611  2020            Yuba           County
# 210965      210985      1262612  2020            Yuba           County
#
#        state_abbr  state_name division_name region_name population_group_code  \
# 60             CA  California       Pacific        West                     2
# 61             CA  California       Pacific        West                     2
# 62             CA  California       Pacific        West                     2
# 63             CA  California       Pacific        West                     2
# 64             CA  California       Pacific        West                     2
# ...           ...         ...           ...         ...                   ...
# 210961         CA  California       Pacific        West                     3
# 210962         CA  California       Pacific        West                     3
# 210963         CA  California       Pacific        West                     3
# 210964         CA  California       Pacific        West                    9B
# 210965         CA  California       Pacific        West                    9B
#
#         ... victim_count                              offense_name  \
# 60      ...            1                              Intimidation
# 61      ...            1                              Intimidation
# 62      ...            1                              Intimidation
# 63      ...            2                        Aggravated Assault
# 64      ...            1  Destruction/Damage/Vandalism of Property
# ...     ...          ...                                       ...
# 210961  ...            1                            Simple Assault
# 210962  ...            1                            Simple Assault
# 210963  ...            1                            Simple Assault
# 210964  ...            1  Destruction/Damage/Vandalism of Property
# 210965  ...            1                        Aggravated Assault
#
#         total_individual_victims                       location_name  \
# 60                           1.0                      School/College
# 61                           1.0                       Other/Unknown
# 62                           1.0                       Other/Unknown
# 63                           2.0             Parking/Drop Lot/Garage
# 64                           1.0                      Residence/Home
# ...                          ...                                 ...
# 210961                       1.0                      Residence/Home
# 210962                       1.0  Highway/Road/Alley/Street/Sidewalk
# 210963                       1.0  Highway/Road/Alley/Street/Sidewalk
# 210964                       1.0  Highway/Road/Alley/Street/Sidewalk
# 210965                       1.0                      Residence/Home
#
#                                  bias_desc  victim_types  multiple_offense  \
# 60          Anti-Black or African American    Individual                 S
# 61                             Anti-Jewish    Individual                 S
# 62                             Anti-Jewish    Individual                 S
# 63                              Anti-Asian    Individual                 S
# 64          Anti-Black or African American    Individual                 S
# ...                                    ...           ...               ...
# 210961  Anti-Other Race/Ethnicity/Ancestry    Individual                 S
# 210962  Anti-Other Race/Ethnicity/Ancestry    Individual                 S
# 210963      Anti-Black or African American    Individual                 S
# 210964      Anti-Black or African American    Individual                 S
# 210965      Anti-Black or African American    Individual                 S
#
#        multiple_bias   bias_cat  county_cat
# 60                 S  race/ethn       urban
# 61                 S   religion       urban
# 62                 S   religion       urban
# 63                 S  race/ethn       urban
# 64                 S  race/ethn       urban
# ...              ...        ...         ...
# 210961             S  race/ethn    suburban
# 210962             S  race/ethn    suburban
# 210963             S  race/ethn    suburban
# 210964             S  race/ethn       rural
# 210965             S  race/ethn       rural
#
# [34752 rows x 29 columns]

# %%
print(len(CA_hc), len(CA_county_hc))
# Out:
# 36205 34752

# %%
pd.DataFrame(CA_county_hc[["bias_cat", "county_cat"]].groupby("county_cat").count())
# Out:
#             bias_cat
# county_cat
# rural            754
# suburban        3478
# urban          30520

# %%
# Create num bias category each year (no mix)
CA_num_bias_hc = pd.DataFrame(CA_county_hc.groupby(["year","county_cat","bias_cat"])["incident_id"].count())
CA_num_bias_hc.reset_index(inplace = True)
CA_num_bias_hc.columns = ["year", "county_cat", "bias_cat", "num_bias_cat"]
#CA_num_bias_hc["prop_bias"] = CA_num_bias_hc["num_bias_cat"]/CA_num_bias_hc.groupby("year")["num_bias_cat"].transform("sum")
CA_num_bias_hc
# Out:
#      year county_cat    bias_cat  num_bias_cat
# 0    1991      urban   race/ethn             3
# 1    1991      urban    religion             2
# 2    1992      urban        lgbt            25
# 3    1992      urban   race/ethn            41
# 4    1992      urban    religion             7
# ..    ...        ...         ...           ...
# 287  2020      urban  disability             3
# 288  2020      urban        lgbt           222
# 289  2020      urban   race/ethn           713
# 290  2020      urban    religion           147
# 291  2020      urban         sex             3
#
# [292 rows x 4 columns]

# %% [markdown]
# ### Interactive visuals
# Year by Year animation of CA map of hate crime incidents
